# %% [markdown]
# ![Screenshot 2023-10-30 005510.png](data:image/png;base64,...)

# %% [markdown]
# # ***Projeto Big Data - MBA Data Sciente***

# %% [markdown]
# #*Superstore Sale*
#
# ***Descreva o problema ou a dor de negócio que você quer explorar na sua análise***
# São dados de vendas do período de 4 anos, com várias informações sobre clientes de uma rede de varejo que comercializa diversos produtos de diversas categorias em várias cidades dos EUA.
#
# Analisando o comportamento dos clientes, em relação aos gastos na empresa, o setor de marketing da empresa poderá segmentar futuras campanhas, personalizando, direcionando, e qual o tipo de apelo comercial para vender os produtos.
#
# ***Quais dados você tem disponível para a análise?***
# Os dados são reais e foram extraídos do link [SuperStore Sale](https://community.tableau.com/s/question/0D54T00000CWeX8SAL/sample-superstore-sales-excelxls), foram feitas simplificações no dataset e trabalhamos em formato CSV.
#
#
#
#
# ***Que hipóteses você pretende validar?***
# Pretendo validar algumas questões, são elas: Quais as cidades com maior faturamento de vendas? Simulando cupons de desconto, qual seria a média do valor vendido antes e depois dos descontos?

# %% [markdown]
# **Perguntas**
# 1.  Qual cidade com maior valor de venda de produtos da Categoria "Office Supples"?
# 2.   Qual o total de vendas por data do pedido?
# 3.   Qual total de vendas por Estado?
# 4.   Quais são as 10 cidades com maior total de vendas?
# 5.   Qual segmento teve o maior total de vendas?
# 6.   Qual o total de vendas por segmento e por ano?
# 7.   Os gestores da empresa estão considerando conceder diferentes faixas de descontos e gostariam de fazer uma simulação com base na regra abaixo:
#     *   Se o Valor_Venda for > U\$1000, recebe 15% de desconto;
#     *   Se o Valor_Venda for < U\$1000, recebe 10% de desconto;
#
#     Quantas vendas receberiam 15% de desconto?
# 8.   Considere que a empresa decida conceder o desconto de 15% do item anterior. Qual seria a média do valor de venda antes e depois do desconto?
# 9.   Qual a média de vendas por segmento, por ano e por mês?
# 10.   Qual o total de vendas por categoria e subcategoria, consiferando somente as Top12 SubcCategorias?

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.10.12

# %%
# Importando as bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %% [markdown]
# ## Carregando o dataset
#
# [Dataset no Github](https://raw.githubusercontent.com/damallys/Projeto_MBA_Big-Data/main/Sample%20-%20SuperStore%20Sale.csv)
#
# https://raw.githubusercontent.com/damallys/Projeto_MBA_Big-Data/main/Sample%20-%20SuperStore%20Sale.csv

# %%
# Importando o conjunto de dados
superstore_sale = pd.read_csv(
    filepath_or_buffer = 'https://raw.githubusercontent.com/damallys/Projeto_MBA_Big-Data/main/Sample%20-%20SuperStore%20Sale.csv',
    sep=',',
    decimal='.'
)

# %%
# Shape
superstore_sale.shape
# Out:
# (9700, 11)

# %%
# Espiando o dataset
superstore_sale.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# ...

# %%
# Amostra dos dados
superstore_sale.tail()
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 9695  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9696  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9697  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9698  CA-2017-105291  30/10/2017   SP-20920     Consumer  United States
# 9699  CA-2018-147032  31/07/2018   LB-16795  Home Office  United States
#
#                Cidade      Estado       ID_Produto        Categoria  \
# 9695        Inglewood  California  OFF-PA-10004569  Office Supplies
# 9696        Inglewood  California  OFF-AP-10000027  Office Supplies
# 9697        Inglewood  California  TEC-PH-10000675       Technology
# 9698  San Luis Obispo  California  OFF-FA-10003059  Office Supplies
# 9699       Wilmington    Delaware  OFF-PA-10003256  Office Supplies
#
#      SubCategoria  Valor_Venda
# 9695        Paper       22.830
# 9696   Appliances       54.320
# ...

# %% [markdown]
# ## Análise Exploratória

# %%
# Colunas do conjunto de dados
superstore_sale.columns
# Out:
# Index(['ID_Pedido', 'Data_Pedido', 'ID_Cliente', 'Segmento', 'Pais', 'Cidade',
#        'Estado', 'ID_Produto', 'Categoria', 'SubCategoria', 'Valor_Venda'],
#       dtype='object')

# %%
# Verificando o tipo de dados de cada coluna
superstore_sale.dtypes
# Out:
# ID_Pedido        object
# Data_Pedido      object
# ID_Cliente       object
# Segmento         object
# Pais             object
# Cidade           object
# Estado           object
# ID_Produto       object
# Categoria        object
# SubCategoria     object
# Valor_Venda     float64
# dtype: object

# %% [markdown]
# Observamos que a maioria das variáveis são object (dados categóricos), apenas a variável Valor_Venda é tipo float64 (dado quantitativo)

# %%
# Resumo estatístico da coluna com o valor de venda
superstore_sale['Valor_Venda'].describe()
# Out:
# count     9700.000000
# mean       230.469892
# std        627.504252
# min          0.444000
# 25%         17.248000
# 50%         54.272000
# 75%        209.932500
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %% [markdown]
# Resumo da variável Venda:
# A média das vendas foi U\$230.47, desvio padrão U\$627.50. Menor venda foi U\$ 0.44, maior venda foi U\$ 22638.48. Isso (diferença dos valores mín e máx), ajuda explicar o porque de um desvio padrão tão grande em relação nesse dataset.

# %%
# Verificando se há registros duplicados
superstore_sale[superstore_sale.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID_Pedido, Data_Pedido, ID_Cliente, Segmento, Pais, Cidade, Estado, ID_Produto, Categoria, SubCategoria, Valor_Venda]
# Index: []

# %% [markdown]
# Não existe registro duplicado, nem valores ausentes nesse dataset

# %%
# Verificando de há valores ausentes
superstore_sale.isnull().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Cidade          0
# Estado          0
# ID_Produto      0
# Categoria       0
# SubCategoria    0
# Valor_Venda     0
# dtype: int64

# %%
dados = superstore_sale.copy()

# %%
dados.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# ...

# %% [markdown]
# ## Perguntas de Negócio:

# %% [markdown]
# ### 1- Qual Cidade com Maior Valor de Venda de Produtos da Categoria 'Office Supplies'?

# %%
# Primeiro filtramos o dataframe com os registros da categoria que desejamos
dados_p1 = dados[dados['Categoria'] == 'Office Supplies']

# %%
# Em seguida agrupamos por cidade e calculamos o total de valor_venda
dados_p1_total = dados_p1.groupby('Cidade')['Valor_Venda'].sum()

# %%
# Então encontramos a cidade com maior valor de venda
cidade_maior_venda = dados_p1_total.idxmax()
print("Cidade com maior valor de venda para 'Office Supplies':", cidade_maior_venda)
# Out:
# Cidade com maior valor de venda para 'Office Supplies': New York City

# %%
# Para conferir o resultado
dados_p1_total.sort_values(ascending = False)
# Out:
# Cidade
# New York City    68362.814
# Los Angeles      47098.100
# San Francisco    41771.198
# Seattle          34856.878
# Philadelphia     29313.687
#                    ...
# Ormond Beach         2.808
# Pensacola            2.214
# Jupiter              2.064
# Elyria               1.824
# Abilene              1.392
# Name: Valor_Venda, Length: 480, dtype: float64

# %% [markdown]
# **Resposta:** Cidade com maior valor de venda para 'Office Supplies': New York City

# %% [markdown]
# ### 2-	Qual o total de vendas por data do pedido?

# %%
# Calculamos o total de vendas para cada data de pedido
dados_p2 = dados.groupby('Data_Pedido')['Valor_Venda'].sum()

# %%
dados_p2.head()
# Out:
# Data_Pedido
# 01/01/2018    1481.8280
# 01/02/2015     468.9000
# 01/02/2017     161.9700
# 01/03/2015    2203.1510
# 01/03/2016    1642.1744
# Name: Valor_Venda, dtype: float64

# %% [markdown]
# **Obs:** Estamos aqui tratando data com pedido como variável categórica e não como série temporal. Se a pergunta fosse "ao logo do tempo" essa resposta não seria a ideal.

# %%
# Gráfico de série temporais
plt.figure(figsize = (20, 6))
dados_p2.plot(x = 'Data_Pedido', y = 'Valor_Venda', color = 'purple')
plt.title('Total de Vendas Por Data do Pedido')
plt.show()

# %% [markdown]
# ### 3-	Qual o total de vendas por Estado?

# %%
# Agrupamos por estado e calculamos o total de vendas
dados_p3 = dados.groupby('Estado')['Valor_Venda'].sum().reset_index()

# %%
# Gráfico de Barras Invertidas
plt.figure(figsize = (16, 6))
sns.set_palette('coolwarm')
sns.barplot(data = dados_p3,
            x = 'Valor_Venda',
            y = 'Estado').set(title = 'Vendas Por Estado')
plt.xticks(rotation = 80)
plt.show()

# %%
# Gráfico de Barras
plt.figure(figsize = (16, 6))
sns.set_palette('coolwarm')
sns.barplot(data = dados_p3,
            y = 'Valor_Venda',
            x = 'Estado').set(title = 'Vendas Por Estado')
plt.xticks(rotation = 80)
plt.show()

# %% [markdown]
# ### 4-	Quais são as 10 cidades com maior total de faturamento?

# %%
# Agrupamos por cidade, calculamos o total de vendas e ordenamos listando somente os 10 primeiros registros
dados_p4 = dados.groupby('Cidade')['Valor_Venda'].sum().reset_index().sort_values(by = 'Valor_Venda',
                                                                                    ascending = False).head(10)

# %%
dados_p4.head(10)
# Out:
#             Cidade  Valor_Venda
# 327  New York City  251749.2190
# 265    Los Angeles  171654.6330
# 450        Seattle  114725.4780
# 436  San Francisco  107489.9520
# 372   Philadelphia  107197.8030
# 207        Houston   61590.1868
# 435      San Diego   47458.3790
# 80         Chicago   46974.3430
# 216   Jacksonville   44713.1830
# 123        Detroit   42446.9440

# %%
# Gráfico de Barras
plt.figure(figsize = (16, 6))
sns.set_palette('coolwarm')
sns.barplot(data = dados_p4,
            y = 'Valor_Venda',
            x = 'Cidade').set(title = 'As 10 Cidades com Maior Total de Vendas')
plt.show()

# %% [markdown]
# **Resposta:**
# As dez cidades com maior total de vendas são: New York, Los Angeles, Seattle, San Francisco, Philadelphia, Houston, San Diego, Chicago, Jacksonville, Detroit.

# %% [markdown]
# ### 5-	Qual segmento teve o maior total de vendas?

# %%
# Agrupamos por segmento e calculamos o total de vendas
dados_p5 = dados.groupby('Segmento')['Valor_Venda'].sum().reset_index().sort_values(by = 'Valor_Venda',
                                                                                      ascending = False)

# %%
dados_p5.head()
# Out:
#       Segmento   Valor_Venda
# 0     Consumer  1.133834e+06
# 1    Corporate  6.792322e+05
# 2  Home Office  4.224914e+05

# %% [markdown]
# O valor venda foi entregue por notação científica, não há nada de errado nisso, é que o valor é muito grande. o pacote pandas converteu esse valor, para notação científica, é padrão do pacote. Vamos formatar esses dados, convertendo os dados em valor absoluto.

# %%
# Função para converter os dados em valor absoluto
def autopct_format(values):
    def my_format(pct):
        total = sum(values)
        val = int(round(pct * total / 100.0))
        return ' $ {v:d}'.format(v = val)
    return my_format

# %%
# Gráfico de Pizza Círculo central

# Tamanho da figura
plt.figure(figsize = (16, 6))

# Gráfico de pizza
plt.pie(dados_p5['Valor_Venda'],
        labels = dados_p5['Segmento'],
        autopct = autopct_format(dados_p5['Valor_Venda']),
        startangle = 90)

# Limpa o círculo central
centre_circle = plt.Circle((0, 0), 0.82, fc = 'white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Labels e anotações
plt.annotate(text = 'Total de Vendas: ' + '$ ' + str(int(sum(dados_p5['Valor_Venda']))), xy = (-0.25, 0))
plt.title('Total de Vendas Por Segmento')
plt.show()

# %% [markdown]
# **Resposta:** O segmento de Consumidor é o que teve o maior total de vendas.

# %% [markdown]
# ### 6-	Qual o total de vendas por segmento e por ano?

# %%
dados.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# ...

# %%
# Convertemos a coluna de data para o tipo datetime para obter o formato adequado
dados['Data_Pedido'] = pd.to_datetime(dados['Data_Pedido'], dayfirst = True)

# %%
dados.dtypes
# Out:
# ID_Pedido               object
# Data_Pedido     datetime64[ns]
# ID_Cliente              object
# Segmento                object
# Pais                    object
# Cidade                  object
# Estado                  object
# ID_Produto              object
# Categoria               object
# SubCategoria            object
# Valor_Venda            float64
# dtype: object

# %%
# Extraíndo o ano, criando nova variável
dados['Ano'] = dados['Data_Pedido'].dt.year

# %%
dados.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano
# 0     261.9600  2017
# 1     731.9400  2017
# 2      14.6200  2017
# ...

# %%
# Total de vendas por segmento e por ano
dados_p6 = dados.groupby(['Ano', 'Segmento'])['Valor_Venda'].sum()

# %%
dados_p6
# Out:
# Ano   Segmento
# 2015  Consumer       256719.9166
#       Corporate      125819.5957
#       Home Office     88229.0878
# 2016  Consumer       265295.2593
#       Corporate      114643.1229
#       Home Office     74134.1332
# 2017  Consumer       288459.5572
#       Corporate      203266.7398
#       Home Office    103639.6270
# 2018  Consumer       323359.6019
#       Corporate      235502.7284
#       Home Office    156488.5849
# Name: Valor_Venda, dtype: float64

# %% [markdown]
# ### 7-	Os gestores da empresa estão considerando conceder diferentes faixas de descontos e gostariam de fazer uma simulação com base na regra abaixo:
#
# *  Se o Valor_Venda for maior que 1000 recebe 15% de desconto.
# *  Se o Valor_Venda for menor que 1000 recebe 10% de desconto.
#
# Quantas vendas receberiam 15% de desconto?

# %%
# Cria uma nova coluna de acordo com a regra definida acima
dados['Desconto'] = np.where(dados['Valor_Venda'] > 1000, 0.15, 0.10)

# %%
dados.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano  Desconto
# 0     261.9600  2017       0.1
# ...

# %%
# Total por cada valor da variável
dados['Desconto'].value_counts()
# Out:
# 0.10    9243
# 0.15     457
# Name: Desconto, dtype: int64

# %%
print('No Total 457 Vendas Receberiam Desconto de 15%.')
# Out:
# No Total 457 Vendas Receberiam Desconto de 15%.

# %% [markdown]
# ### 8-	Considere que a empresa decida conceder o desconto de 15% do item anterior. Qual seria a média do valor de venda antes e depois do desconto?

# %%
# Criamos uma coluna calculando o valor de venda menos o desconto
dados['Valor_Venda_Desconto'] = dados['Valor_Venda'] - (dados['Valor_Venda'] * dados['Desconto'])

# %%
dados.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano  Desconto  Valor_Venda_Desconto
# ...

# %%
# Filtrando as vendas antes do desconto de 15%
dados_p8_vendas_antes_desconto = dados.loc[dados['Desconto'] == 0.15, 'Valor_Venda']

# %%
# Filtrando as vendas depois do desconto de 15%
dados_p8_vendas_depois_desconto = dados.loc[dados['Desconto'] == 0.15, 'Valor_Venda_Desconto']

# %%
# Calcula a média das vendas antes do desconto de 15%
media_vendas_antes_desconto = dados_p8_vendas_antes_desconto.mean()

# %%
# Calcula a média das vendas depois do desconto de 15%
media_vendas_depois_desconto = dados_p8_vendas_depois_desconto.mean()

# %%
print("Média das vendas antes do desconto de 15%:", round(media_vendas_antes_desconto, 2))
# Out:
# Média das vendas antes do desconto de 15%: 2116.81

# %%
print("Média das vendas depois do desconto de 15%:", round(media_vendas_depois_desconto, 2))
# Out:
# Média das vendas depois do desconto de 15%: 1799.29

# %% [markdown]
# **Resposta:** A média das vendas antes do desconto de 15% era U\$2116,81 dólares e depois do desconto a média de vendas passou a ser U\$1799,29 dólares.

# %% [markdown]
# ### 9-	Qual a média de vendas por segmento, por ano e por mês?

# %%
# Extraímos o mês e gravamos em uma nova variável
dados['Mes'] = dados['Data_Pedido'].dt.month

# %%
dados.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano  Desconto  Valor_Venda_Desconto  Mes
# ...

# %%
# Agrupamos por ano, mês e segmento e calculamos estatísticas de agregação
dados_p9 = dados.groupby(['Ano', 'Mes', 'Segmento'])['Valor_Venda'].agg([np.sum, np.mean, np.median])

# %%
dados_p9
# Out:
#                              sum        mean  median
# Ano  Mes Segmento
# 2015 1   Consumer      6896.6290  146.736787  36.440
#          Corporate     1701.5280  130.886769  51.940
#          Home Office   5607.5500  329.855882  62.820
#      2   Consumer      3167.8540  117.327926  22.776
#          Corporate      623.1180   69.235333  62.310
# ...                          ...         ...     ...
# 2018 11  Corporate    44357.9862  341.215278  79.530
#          Home Office  24009.3840  247.519423  56.560
#      12  Consumer     48107.4558  183.616244  52.533
#          Corporate    20524.4320  153.167403  46.460
#          Home Office  13022.3910  224.523983  49.260
#
# [144 rows x 3 columns]

# %%
# Vamos extrair os níveis
anos = dados_p9.index.get_level_values(0)
meses = dados_p9.index.get_level_values(1)
segmentos = dados_p9.index.get_level_values(2)

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.relplot.html

# %%
# Gráfico de linha
plt.figure(figsize = (12, 6))
sns.set()
fig1 = sns.relplot(kind = 'line',
                   data = dados_p9,
                   y = 'mean',
                   x = meses,
                   hue = segmentos,
                   col = anos,
                   col_wrap = 2)
plt.show()

# %% [markdown]
# ### 10-	Qual o total de vendas por categoria e subcategoria, considerando somente as top 12 subcategorias?

# %%
dados.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano  Desconto  Valor_Venda_Desconto  Mes
# ...

# %%
# Agrupamos por categoria e subcategoria e calculamos a soma somente para variáveus numéricas
dados_p10 = dados.groupby(['Categoria',
                             'SubCategoria']).sum(numeric_only = True).sort_values('Valor_Venda',
                                                                                   ascending = False).head(12)

# %%
# Convertemos a coluna Valor_Venda em número inteiro e classificamos por categoria
dados_p10 = dados_p10[['Valor_Venda']].astype(int).sort_values(by = 'Categoria').reset_index()

# %% [markdown]
# ***Obs:*** Classificar o item acima por categoria é importante para preencher o gráfico com as subcategorias para cada categoria de forma ordenada.

# %%
# Dataframe com categorias e subcategorias
dados_p10
# Out:
#           Categoria SubCategoria  Valor_Venda
# 0         Furniture       Chairs       317919
# 1         Furniture       Tables       202083
# 2         Furniture    Bookcases       108045
# 3         Furniture  Furnishings        88862
# 4   Office Supplies      Storage       216188
# 5   Office Supplies      Binders       194723
# 6   Office Supplies   Appliances       104061
# 7   Office Supplies        Paper        76312
# 8        Technology       Phones       325271
# 9        Technology     Machines       189238
# 10       Technology  Accessories       162791
# 11       Technology      Copiers       146248

# %%
# Criamos outro dataframe somente com os totais por categoria
dados_p10_cat = dados_p10.groupby('Categoria').sum(numeric_only = True).reset_index()

# %%
# Dataframe com categorias
dados_p10_cat
# Out:
#          Categoria  Valor_Venda
# 0        Furniture       716909
# 1  Office Supplies       591284
# 2       Technology       823548

# %%
# Listas de cores para categorias
cores_categorias = ['#5d00de',
                    '#0ee84f',
                    '#e80e27']

# %%
# Listas de cores para subcategorias
cores_subcategorias = ['#aa8cd4',
                       '#aa8cd5',
                       '#aa8cd6',
                       '#aa8cd7',
                       '#26c957',
                       '#26c958',
                       '#26c959',
                       '#26c960',
                       '#e65e65',
                       '#e65e66',
                       '#e65e67',
                       '#e65e68']

# %%
# Gráfico

# Tamanho da figura
fig, ax = plt.subplots(figsize = (18,12))

# Gráfico das categorias
p1 = ax.pie(dados_p10_cat['Valor_Venda'],
            radius = 1,
            labels = dados_p10_cat['Categoria'],
            wedgeprops = dict(edgecolor = 'white'),
            colors = cores_categorias)

# Gráfico das subcategorias
p2 = ax.pie(dados_p10['Valor_Venda'],
            radius = 0.9,
            labels = dados_p10['SubCategoria'],
            autopct = autopct_format(dados_p10['Valor_Venda']),
            colors = cores_subcategorias,
            labeldistance = 0.7,
            wedgeprops = dict(edgecolor = 'white'),
            pctdistance = 0.53,
            rotatelabels = True)

# Limpa o centro do círculo
centre_circle = plt.Circle((0, 0), 0.6, fc = 'white')

# Labels e anotações
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.annotate(text = 'Total de Vendas: ' + '$ ' + str(int(sum(dados_p10['Valor_Venda']))), xy = (-0.2, 0))
plt.title('Total de Vendas Por Categoria e Top 12 SubCategorias')
plt.show()

# %% [markdown]
# ## Conclusão

# %% [markdown]
# Com base no período de 4 anos que consta no dataset, podemos tirar algumas conclusões a respeito do comportamento dos clientes, da SuperStore.
#
# O maior faturamento na categoria "Office Supples" é na cidade de New York.
#
# As dez cidades com maior faturamento de venda são: New York, Los Angeles, Seattle, San Francisco, Philadelphia, Houston, San Diego, Chicago, Jacksonville e Detroit.
#
# O segmento que teve o maior faturamento foi Consumidor, com total de U\$ 113.383,40 dólares de vendas.
#
# Fazendo uma simulação, considerando as diferentes faixas de descontos, que os gestores da empresa desejam conceder aos clientes, temos que, no total 9.243 vendas receberiam o desconto de 10% e 457 vendas receberiam desconto de 15%.
#
# A média das vendas antes do desconto de 15% era de U\$ 2.116,81 dólares, e depois do desconto a média de vendas passou a ser de U\$ 1.799,29 dólares.
